# %% [markdown]
# # Parsing Reports
#
# This notebook parses the contents of reports/ to understand the speed and reliability of AGC-running experiments.

# %%
import awkward as ak
import pickle as pkl

# %%
REMOTE_NONE_NONE = "RemoteRead_reports20240822_221923_250_None_None.pkl"
REMOTE_5_NONE = "RemoteRead_reports20240822_202120_250_5_None.pkl"
XCACHE_5_NONE_FIRST = "Xcache_reports20240822_204219_250_5_None.pkl"
XCACHE_5_NONE_SECOND = "Xcache_reports20240822_205535_250_5_None.pkl"
XCACHE_NONE_NONE_FIRST = "Xcache_reports20240823_192620_250_None_None.pkl"

# %%
class ParsedReport:
    def __init__(self,rep):
        with open(rep,"rb") as f:
            self.reports = pkl.load(f)
        self.errors = {}
        for dset in self.reports.keys():
            self.errors[dset] = self.reports[dset][~ak.is_none(self.reports[dset].message)]

        #Calculate some aggregate metrics
        self._chunk_fail_rate()
        self._count_chunks()
        self._file_fail_rate()
        self._count_files()
        self._count_sites()
        self._count_messages()

    def print_metrics(self,sites=False):
        print("AGGREGATE INFO:\n----------------------------------------------------")
        print(f"Total number of files: {self.num_files}")
        print(f"Total file read error rate: {100*self.tot_file_fail_rate}%")
        print(f"Total number of chunks: {self.num_chunks}")
        print(f"Total chunk read error rate: {100*self.tot_chunk_fail_rate}%")
        
        print("\n========================================================\n")
        print("PER-DATASET INFO:\n----------------------------------------------------")
        for dset in self.reports.keys():
            print(f"Dataset: {dset}")
            print(f"\tNumber of files: {len(set(self.reports[dset].args[:,0]))}")
            print(f"\tFile read error rate: {100*self.file_fail_rates[dset]}%")
            print(f"\tNumber of chunks: {ak.num(self.reports[dset],axis=0)}")
            print(f"\tChunk read error rate: {100*self.chunk_fail_rates[dset]}%")
        print("\n========================================================\n")
        print("ERROR MESSAGES:\n----------------------------------------------------")
        for msg in self.messages:
            print(f"Error message: {msg}")
            print(f"\tChunks with this message: {self.messages_count[msg]}")
        if not sites:
            return
        print("\n========================================================\n")
        print("SITES INFO:\n----------------------------------------------------")
        for site in self.site_counts.keys():
            print(f"Site: {site}")
            print(f"\tNumber of files: {self.site_counts[site]}")
            print(f"\tFile read failure rate at this site: {100*self.site_error_counts[site]/self.site_counts[site]}%")

    def _chunk_fail_rate(self):
        self.chunk_fail_rates = {}
        for dset in self.reports.keys():
            self.chunk_fail_rates[dset] = ak.num(self.errors[dset],axis=0)/ak.num(self.reports[dset],axis=0)

    def _count_chunks(self):
        self.num_chunks = 0
        self.num_error_chunks = 0
        for dset in self.reports.keys():
            self.num_chunks += ak.num(self.reports[dset],axis=0)
            self.num_error_chunks += ak.num(self.errors[dset],axis=0)
        self.tot_chunk_fail_rate = self.num_error_chunks/self.num_chunks

    def _file_fail_rate(self):
        self.file_fail_rates = {}
        for dset in self.reports.keys():
            num_files = len(set(self.reports[dset].args[:,0]))
            num_error_files = len(set(self.errors[dset].args[:,0]))
            self.file_fail_rates[dset] = num_error_files/num_files

    def _count_files(self):
        self.num_files = 0
        self.num_error_files = 0
        for dset in self.reports.keys():
            self.num_files += len(set(self.reports[dset].args[:,0]))
            self.num_error_files += len(set(self.errors[dset].args[:,0]))
        self.tot_file_fail_rate = self.num_error_files/self.num_files

    def _count_sites(self):
        self.site_counts = {}
        self.site_error_counts = {}
        for dset in self.reports.keys():
            files = set(self.reports[dset].args[:,0])
            for f in files:
                file_count = ak.sum((self.reports[dset].args[:,0] == f) & (self.reports[dset].args[:,2] == "0"))
                error_file_count = ak.sum((self.errors[dset].args[:,0] == f) & (self.errors[dset].args[:,2] == "0"))
                site = f.split('/store')[0]
                self.site_counts[site] = self.site_counts.get(site,0) + file_count
                self.site_error_counts[site] = self.site_error_counts.get(site,0) + error_file_count
                

    def _count_messages(self):
        _messages_list = []
        for dset in self.errors.keys():
            _messages_list += list(set(self.errors[dset].message))
        self.messages = set(_messages_list)
        self.messages_count = {}
        for dset in self.errors.keys():
            if ak.num(self.errors[dset].message,axis=0) == 0:
                continue
            for msg in self.messages:
                self.messages_count[msg] = self.messages_count.get(msg,0) + ak.sum(self.errors[dset].message == msg)

# %% [markdown]
# ## Results for Remote Reading, Max 5 Files per Sample

# %%
rep1 = ParsedReport(f"reports/{REMOTE_5_NONE}")

# %%
rep1.print_metrics(sites=True)
# Out:
# AGGREGATE INFO:
# ----------------------------------------------------
# Total number of files: 40
# Total file read error rate: 2.5%
# Total number of chunks: 3209
# Total chunk read error rate: 4.799002804612028%
#
# ========================================================
#
# PER-DATASET INFO:
# ----------------------------------------------------
# Dataset: /TTToHadronic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL18NanoAOD-106X_upgrade2018_realistic_v11_L1v1-v1/NANOAODSIM
# 	Number of files: 5
# 	File read error rate: 0.0%
# 	Number of chunks: 532
# 	Chunk read error rate: 0.0%
# Dataset: /ST_s-channel_4f_hadronicDecays_TuneCP5_13TeV-amcatnlo-pythia8/RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1/NANOAODSIM
# 	Number of files: 5
# 	File read error rate: 0.0%
# 	Number of chunks: 292
# 	Chunk read error rate: 0.0%
# Dataset: /ST_t-channel_top_4f_InclusiveDecays_TuneCP5_13TeV-powheg-madspin-pythia8/RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1/NANOAODSIM
# 	Number of files: 5
# 	File read error rate: 0.0%
# 	Number of chunks: 503
# 	Chunk read error rate: 0.0%
# Dataset: /ST_t-channel_antitop_4f_InclusiveDecays_TuneCP5_13TeV-powheg-madspin-pythia8/RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1/NANOAODSIM
# 	Number of files: 5
# 	File read error rate: 0.0%
# 	Number of chunks: 125
# 	Chunk read error rate: 0.0%
# Dataset: /ST_tW_antitop_5f_inclusiveDecays_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2/NANOAODSIM
# 	Number of files: 5
# 	File read error rate: 0.0%
# 	Number of chunks: 144
# 	Chunk read error rate: 0.0%
# Dataset: /ST_tW_top_5f_inclusiveDecays_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2/NANOAODSIM
# 	Number of files: 5
# 	File read error rate: 0.0%
# 	Number of chunks: 55
# 	Chunk read error rate: 0.0%
# Dataset: /WJetsToLNu_1J_TuneCP5_13TeV-amcatnloFXFX-pythia8/RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1/NANOAODSIM
# 	Number of files: 5
# 	File read error rate: 20.0%
# 	Number of chunks: 925
# 	Chunk read error rate: 16.64864864864865%
# Dataset: /WJetsToLNu_2J_TuneCP5_13TeV-amcatnloFXFX-pythia8/RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1/NANOAODSIM
# 	Number of files: 5
# 	File read error rate: 0.0%
# 	Number of chunks: 633
# 	Chunk read error rate: 0.0%
#
# ========================================================
#
# ERROR MESSAGES:
# ----------------------------------------------------
# Error message: Failed to open file: [ERROR] Server responded with an error: [3005] User cms001 has hit the limit of 16 open files
#
# 	Chunks with this message: 26
# Error message: File did not open properly: [ERROR] Server responded with an error: [3005] User cms001 has hit the limit of 16 open files
#
# 	Chunks with this message: 128
#
# ========================================================
#
# SITES INFO:
# ----------------------------------------------------
# Site: 'root://cmsdcadisk.fnal.gov:1094//dcache/uscmsdisk
# 	Number of files: 7
# 	File read failure rate at this site: 0.0%
# Site: 'root://eoscms.cern.ch:1094//eos/cms
# 	Number of files: 2
# 	File read failure rate at this site: 0.0%
# Site: 'root://xrootd.cmsaf.mit.edu:1094/
# 	Number of files: 1
# 	File read failure rate at this site: 0.0%
# Site: 'root://xrootd01.jinr-t1.ru:1094//pnfs/jinr-t1.ru/data/cms
# 	Number of files: 4
# 	File read failure rate at this site: 0.0%
# Site: 'root://ccxrdcms.in2p3.fr:1094/
# 	Number of files: 1
# 	File read failure rate at this site: 0.0%
# Site: 'root://grid-cms-xrootd.physik.rwth-aachen.de:1094/
# 	Number of files: 1
# 	File read failure rate at this site: 0.0%
# Site: 'root://cmsdcache-kit-disk.gridka.de:1094/
# 	Number of files: 2
# 	File read failure rate at this site: 0.0%
# Site: 'root://xrootd-cmst1-door.pic.es:1094//pnfs/pic.es/data/cms/disk
# 	Number of files: 2
# 	File read failure rate at this site: 0.0%
# Site: 'root://dcache-cms-xrootd.desy.de:1094/
# 	Number of files: 3
# 	File read failure rate at this site: 0.0%
# Site: 'root://xrootd-local.unl.edu:1094/
# 	Number of files: 4
# 	File read failure rate at this site: 0.0%
# Site: 'root://t3se01.psi.ch:1094/
# 	Number of files: 1
# 	File read failure rate at this site: 0.0%
# Site: 'root://cmseos.fnal.gov:1094//eos/uscms
# 	Number of files: 1
# 	File read failure rate at this site: 0.0%
# Site: 'root://sbgdcache.in2p3.fr:1094/
# 	Number of files: 3
# 	File read failure rate at this site: 0.0%
# Site: 'root://gaexrdoor.ciemat.es:1094/
# 	Number of files: 3
# 	File read failure rate at this site: 0.0%
# Site: 'root://xrootd-cms.infn.it:1194/
# 	Number of files: 1
# 	File read failure rate at this site: 0.0%
# Site: 'root://cmsxrootd.hep.wisc.edu:1094/
# 	Number of files: 1
# 	File read failure rate at this site: 0.0%
# Site: 'root://cms-xrdr.sdfarm.kr:1094//xrd
# 	Number of files: 1
# 	File read failure rate at this site: 0.0%
# Site: 'root://cmsxrd.ts.infn.it:1094/
# 	Number of files: 1
# 	File read failure rate at this site: 100.0%
# Site: 'root://k8s-redir.ultralight.org:1094/
# 	Number of files: 1
# 	File read failure rate at this site: 0.0%

# %% [markdown]
# ## Results for XCache Reading, Max 5 Files per Sample, Files not yet in XCache

# %%
rep2 = ParsedReport(f"reports/{XCACHE_5_NONE_FIRST}")

# %%
rep2.print_metrics(sites=True)
# Out:
# AGGREGATE INFO:
# ----------------------------------------------------
# Total number of files: 40
# Total file read error rate: 2.5%
# Total number of chunks: 3209
# Total chunk read error rate: 2.243689622935494%
#
# ========================================================
#
# PER-DATASET INFO:
# ----------------------------------------------------
# Dataset: /TTToHadronic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL18NanoAOD-106X_upgrade2018_realistic_v11_L1v1-v1/NANOAODSIM
# 	Number of files: 5
# 	File read error rate: 0.0%
# 	Number of chunks: 532
# 	Chunk read error rate: 0.0%
# Dataset: /ST_s-channel_4f_hadronicDecays_TuneCP5_13TeV-amcatnlo-pythia8/RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1/NANOAODSIM
# 	Number of files: 5
# 	File read error rate: 0.0%
# 	Number of chunks: 292
# 	Chunk read error rate: 0.0%
# Dataset: /ST_t-channel_top_4f_InclusiveDecays_TuneCP5_13TeV-powheg-madspin-pythia8/RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1/NANOAODSIM
# 	Number of files: 5
# 	File read error rate: 0.0%
# 	Number of chunks: 503
# 	Chunk read error rate: 0.0%
# Dataset: /ST_t-channel_antitop_4f_InclusiveDecays_TuneCP5_13TeV-powheg-madspin-pythia8/RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1/NANOAODSIM
# 	Number of files: 5
# 	File read error rate: 0.0%
# 	Number of chunks: 125
# 	Chunk read error rate: 0.0%
# Dataset: /ST_tW_antitop_5f_inclusiveDecays_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2/NANOAODSIM
# 	Number of files: 5
# 	File read error rate: 20.0%
# 	Number of chunks: 144
# 	Chunk read error rate: 50.0%
# Dataset: /ST_tW_top_5f_inclusiveDecays_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2/NANOAODSIM
# 	Number of files: 5
# 	File read error rate: 0.0%
# 	Number of chunks: 55
# 	Chunk read error rate: 0.0%
# Dataset: /WJetsToLNu_1J_TuneCP5_13TeV-amcatnloFXFX-pythia8/RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1/NANOAODSIM
# 	Number of files: 5
# 	File read error rate: 0.0%
# 	Number of chunks: 925
# 	Chunk read error rate: 0.0%
# Dataset: /WJetsToLNu_2J_TuneCP5_13TeV-amcatnloFXFX-pythia8/RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1/NANOAODSIM
# 	Number of files: 5
# 	File read error rate: 0.0%
# 	Number of chunks: 633
# 	Chunk read error rate: 0.0%
#
# ========================================================
#
# ERROR MESSAGES:
# ----------------------------------------------------
# Error message: Bytes failed to read from open file: [ERROR] Operation expired
# 	Chunks with this message: 1
# Error message: Bytes failed to read from open file: [ERROR] Server responded with an error: [3034] aio file read timed out
#
# 	Chunks with this message: 71
#
# ========================================================
#
# SITES INFO:
# ----------------------------------------------------
# Site: 'root://cmsxcache.hep.wisc.edu:1094/
# 	Number of files: 40
# 	File read failure rate at this site: 2.5%

# %% [markdown]
# ## Results for XCache Reading, Max 5 Files per Sample, Files already in XCache

# %%
rep3 = ParsedReport(f"reports/{XCACHE_5_NONE_SECOND}")

# %%
rep3.print_metrics()
# Out:
# AGGREGATE INFO:
# ----------------------------------------------------
# Total number of files: 40
# Total file read error rate: 2.5%
# Total number of chunks: 3209
# Total chunk read error rate: 2.243689622935494%
#
# ========================================================
#
# PER-DATASET INFO:
# ----------------------------------------------------
# Dataset: /TTToHadronic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL18NanoAOD-106X_upgrade2018_realistic_v11_L1v1-v1/NANOAODSIM
# 	Number of files: 5
# 	File read error rate: 0.0%
# 	Number of chunks: 532
# 	Chunk read error rate: 0.0%
# Dataset: /ST_s-channel_4f_hadronicDecays_TuneCP5_13TeV-amcatnlo-pythia8/RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1/NANOAODSIM
# 	Number of files: 5
# 	File read error rate: 0.0%
# 	Number of chunks: 292
# 	Chunk read error rate: 0.0%
# Dataset: /ST_t-channel_top_4f_InclusiveDecays_TuneCP5_13TeV-powheg-madspin-pythia8/RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1/NANOAODSIM
# 	Number of files: 5
# 	File read error rate: 0.0%
# 	Number of chunks: 503
# 	Chunk read error rate: 0.0%
# Dataset: /ST_t-channel_antitop_4f_InclusiveDecays_TuneCP5_13TeV-powheg-madspin-pythia8/RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1/NANOAODSIM
# 	Number of files: 5
# 	File read error rate: 0.0%
# 	Number of chunks: 125
# 	Chunk read error rate: 0.0%
# Dataset: /ST_tW_antitop_5f_inclusiveDecays_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2/NANOAODSIM
# 	Number of files: 5
# 	File read error rate: 20.0%
# 	Number of chunks: 144
# 	Chunk read error rate: 50.0%
# Dataset: /ST_tW_top_5f_inclusiveDecays_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2/NANOAODSIM
# 	Number of files: 5
# 	File read error rate: 0.0%
# 	Number of chunks: 55
# 	Chunk read error rate: 0.0%
# Dataset: /WJetsToLNu_1J_TuneCP5_13TeV-amcatnloFXFX-pythia8/RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1/NANOAODSIM
# 	Number of files: 5
# 	File read error rate: 0.0%
# 	Number of chunks: 925
# 	Chunk read error rate: 0.0%
# Dataset: /WJetsToLNu_2J_TuneCP5_13TeV-amcatnloFXFX-pythia8/RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1/NANOAODSIM
# 	Number of files: 5
# 	File read error rate: 0.0%
# 	Number of chunks: 633
# 	Chunk read error rate: 0.0%
#
# ========================================================
#
# ERROR MESSAGES:
# ----------------------------------------------------
# Error message: Bytes failed to read from open file: [ERROR] Server responded with an error: [3034] aio file read timed out
#
# 	Chunks with this message: 72

# %% [markdown]
# ## Results for Remote Reading, All Files All Chunks

# %%
rep4 = ParsedReport(f"reports/{REMOTE_NONE_NONE}")

# %%
rep4.print_metrics(sites=True)
# Out:
# AGGREGATE INFO:
# ----------------------------------------------------
# Total number of files: 823
# Total file read error rate: 4.981773997569866%
# Total number of chunks: 79735
# Total chunk read error rate: 3.620743713551138%
#
# ========================================================
#
# PER-DATASET INFO:
# ----------------------------------------------------
# Dataset: /TTToHadronic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL18NanoAOD-106X_upgrade2018_realistic_v11_L1v1-v1/NANOAODSIM
# 	Number of files: 329
# 	File read error rate: 3.0395136778115504%
# 	Number of chunks: 31863
# 	Chunk read error rate: 0.7343941248470013%
# Dataset: /ST_s-channel_4f_hadronicDecays_TuneCP5_13TeV-amcatnlo-pythia8/RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1/NANOAODSIM
# 	Number of files: 30
# 	File read error rate: 0.0%
# 	Number of chunks: 1627
# 	Chunk read error rate: 0.0%
# Dataset: /ST_t-channel_top_4f_InclusiveDecays_TuneCP5_13TeV-powheg-madspin-pythia8/RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1/NANOAODSIM
# 	Number of files: 124
# 	File read error rate: 7.258064516129033%
# 	Number of chunks: 15117
# 	Chunk read error rate: 5.351590924125157%
# Dataset: /ST_t-channel_antitop_4f_InclusiveDecays_TuneCP5_13TeV-powheg-madspin-pythia8/RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1/NANOAODSIM
# 	Number of files: 118
# 	File read error rate: 3.389830508474576%
# 	Number of chunks: 8875
# 	Chunk read error rate: 2.4338028169014083%
# Dataset: /ST_tW_antitop_5f_inclusiveDecays_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2/NANOAODSIM
# 	Number of files: 17
# 	File read error rate: 11.76470588235294%
# 	Number of chunks: 569
# 	Chunk read error rate: 4.745166959578207%
# Dataset: /ST_tW_top_5f_inclusiveDecays_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2/NANOAODSIM
# 	Number of files: 43
# 	File read error rate: 4.651162790697675%
# 	Number of chunks: 714
# 	Chunk read error rate: 0.42016806722689076%
# Dataset: /WJetsToLNu_1J_TuneCP5_13TeV-amcatnloFXFX-pythia8/RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1/NANOAODSIM
# 	Number of files: 118
# 	File read error rate: 11.016949152542372%
# 	Number of chunks: 14282
# 	Chunk read error rate: 10.23666153199832%
# Dataset: /WJetsToLNu_2J_TuneCP5_13TeV-amcatnloFXFX-pythia8/RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1/NANOAODSIM
# 	Number of files: 44
# 	File read error rate: 2.272727272727273%
# 	Number of chunks: 6688
# 	Chunk read error rate: 2.0334928229665072%
#
# ========================================================
#
# ERROR MESSAGES:
# ----------------------------------------------------
# Error message: Failed to open file: [ERROR] Socket timeout
# 	Chunks with this message: 156
# Error message: File stat request failed: [ERROR] Operation expired
# 	Chunks with this message: 16
# Error message: Failed to open file: [ERROR] Operation expired
# 	Chunks with this message: 34
# Error message: File did not open properly: [ERROR] Server responded with an error: [3005] User cms001 has hit the limit of 16 open files
#
# 	Chunks with this message: 1596
# Error message: Failed to open file: [ERROR] Server responded with an error: [3005] User cms001 has hit the limit of 16 open files
#
# 	Chunks with this message: 167
# Error message: Bytes failed to read from open file: [ERROR] Operation expired
# 	Chunks with this message: 7
# Error message: File stat request failed: [ERROR] Socket timeout
# 	Chunks with this message: 2
# Error message: File did not open properly: [ERROR] Operation expired
# 	Chunks with this message: 621
# Error message: File did not open properly: [ERROR] Socket timeout
# 	Chunks with this message: 288
#
# ========================================================
#
# SITES INFO:
# ----------------------------------------------------
# Site: 'root://xrootd01.jinr-t1.ru:1094//pnfs/jinr-t1.ru/data/cms
# 	Number of files: 107
# 	File read failure rate at this site: 1.8691588785046729%
# Site: 'root://eoscms.cern.ch:1094//eos/cms
# 	Number of files: 68
# 	File read failure rate at this site: 0.0%
# Site: 'root://xrootd-local.unl.edu:1094/
# 	Number of files: 63
# 	File read failure rate at this site: 0.0%
# Site: 'root://cmsdcadisk.fnal.gov:1094//dcache/uscmsdisk
# 	Number of files: 93
# 	File read failure rate at this site: 0.0%
# Site: 'root://cmsio2.rc.ufl.edu:1094/
# 	Number of files: 17
# 	File read failure rate at this site: 0.0%
# Site: 'root://osg-se.sprace.org.br:1094/
# 	Number of files: 15
# 	File read failure rate at this site: 20.0%
# Site: 'root://xrootd.cmsaf.mit.edu:1094/
# 	Number of files: 18
# 	File read failure rate at this site: 0.0%
# Site: 'root://cmsxrootd.hep.wisc.edu:1094/
# 	Number of files: 33
# 	File read failure rate at this site: 0.0%
# Site: 'root://rdr.echo.stfc.ac.uk:1094/
# 	Number of files: 74
# 	File read failure rate at this site: 0.0%
# Site: 'root://xrootd-vanderbilt.sites.opensciencegrid.org:1094/
# 	Number of files: 20
# 	File read failure rate at this site: 0.0%
# Site: 'root://eos.cms.rcac.purdue.edu:1094/
# 	Number of files: 7
# 	File read failure rate at this site: 0.0%
# Site: 'root://k8s-redir.ultralight.org:1094/
# 	Number of files: 12
# 	File read failure rate at this site: 0.0%
# Site: 'root://redirector.t2.ucsd.edu:1095/
# 	Number of files: 3
# 	File read failure rate at this site: 0.0%
# Site: 'root://ccxrdcms.in2p3.fr:1094/
# 	Number of files: 6
# 	File read failure rate at this site: 0.0%
# Site: 'root://dcache-cms-xrootd.desy.de:1094/
# 	Number of files: 54
# 	File read failure rate at this site: 0.0%
# Site: 'root://grid-cms-xrootd.physik.rwth-aachen.de:1094/
# 	Number of files: 17
# 	File read failure rate at this site: 0.0%
# Site: 'root://gaexrdoor.ciemat.es:1094/
# 	Number of files: 15
# 	File read failure rate at this site: 13.333333333333334%
# Site: 'root://xrootd-cms.infn.it:1194/
# 	Number of files: 15
# 	File read failure rate at this site: 0.0%
# Site: 'root://cmsdcache-kit-disk.gridka.de:1094/
# 	Number of files: 41
# 	File read failure rate at this site: 0.0%
# Site: 'root://xrootd-cmst1-door.pic.es:1094//pnfs/pic.es/data/cms/disk
# 	Number of files: 5
# 	File read failure rate at this site: 0.0%
# Site: 'root://cms-xrdr.sdfarm.kr:1094//xrd
# 	Number of files: 27
# 	File read failure rate at this site: 0.0%
# Site: 'root://maite.iihe.ac.be:1095/
# 	Number of files: 18
# 	File read failure rate at this site: 0.0%
# Site: 'root://xrootd.hep.kbfi.ee:1094/
# 	Number of files: 2
# 	File read failure rate at this site: 0.0%
# Site: 'root://hip-cms-se.csc.fi:1094/
# 	Number of files: 4
# 	File read failure rate at this site: 0.0%
# Site: 'root://hactar01.crc.nd.edu:1094/
# 	Number of files: 17
# 	File read failure rate at this site: 0.0%
# Site: 'root://t2-xrdcms.lnl.infn.it:7070/
# 	Number of files: 14
# 	File read failure rate at this site: 0.0%
# Site: 'root://t3se01.psi.ch:1094/
# 	Number of files: 25
# 	File read failure rate at this site: 20.0%
# Site: 'root://gfe02.grid.hep.ph.ic.ac.uk:1094//pnfs/hep.ph.ic.ac.uk/data/cms
# 	Number of files: 2
# 	File read failure rate at this site: 0.0%
# Site: 'root://cmsxrd.ts.infn.it:1094/
# 	Number of files: 16
# 	File read failure rate at this site: 93.75%
# Site: 'root://cmseos.fnal.gov:1094//eos/uscms
# 	Number of files: 7
# 	File read failure rate at this site: 0.0%
# Site: 'root://sbgdcache.in2p3.fr:1094/
# 	Number of files: 7
# 	File read failure rate at this site: 0.0%
# Site: 'root://cms-se0.kipt.kharkov.ua:1094//dpm/kipt.kharkov.ua/home/cms
# 	Number of files: 1
# 	File read failure rate at this site: 0.0%

# %% [markdown]
# ## Results for XCache Reading, All Files All Chunks

# %%
rep5 = ParsedReport(f"reports/{XCACHE_NONE_NONE_FIRST}")

# %%
rep5.print_metrics()
# Out:
# AGGREGATE INFO:
# ----------------------------------------------------
# Total number of files: 823
# Total file read error rate: 13.365735115431349%
# Total number of chunks: 79735
# Total chunk read error rate: 10.410735561547627%
#
# ========================================================
#
# PER-DATASET INFO:
# ----------------------------------------------------
# Dataset: /TTToHadronic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL18NanoAOD-106X_upgrade2018_realistic_v11_L1v1-v1/NANOAODSIM
# 	Number of files: 329
# 	File read error rate: 17.325227963525837%
# 	Number of chunks: 31863
# 	Chunk read error rate: 14.116687066503466%
# Dataset: /ST_s-channel_4f_hadronicDecays_TuneCP5_13TeV-amcatnlo-pythia8/RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1/NANOAODSIM
# 	Number of files: 30
# 	File read error rate: 6.666666666666667%
# 	Number of chunks: 1627
# 	Chunk read error rate: 16.65642286416718%
# Dataset: /ST_t-channel_top_4f_InclusiveDecays_TuneCP5_13TeV-powheg-madspin-pythia8/RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1/NANOAODSIM
# 	Number of files: 124
# 	File read error rate: 12.903225806451612%
# 	Number of chunks: 15117
# 	Chunk read error rate: 7.944698022094331%
# Dataset: /ST_t-channel_antitop_4f_InclusiveDecays_TuneCP5_13TeV-powheg-madspin-pythia8/RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1/NANOAODSIM
# 	Number of files: 118
# 	File read error rate: 11.864406779661017%
# 	Number of chunks: 8875
# 	Chunk read error rate: 3.988732394366197%
# Dataset: /ST_tW_antitop_5f_inclusiveDecays_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2/NANOAODSIM
# 	Number of files: 17
# 	File read error rate: 11.76470588235294%
# 	Number of chunks: 569
# 	Chunk read error rate: 4.393673110720562%
# Dataset: /ST_tW_top_5f_inclusiveDecays_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2/NANOAODSIM
# 	Number of files: 43
# 	File read error rate: 11.627906976744185%
# 	Number of chunks: 714
# 	Chunk read error rate: 22.969187675070028%
# Dataset: /WJetsToLNu_1J_TuneCP5_13TeV-amcatnloFXFX-pythia8/RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1/NANOAODSIM
# 	Number of files: 118
# 	File read error rate: 7.627118644067797%
# 	Number of chunks: 14282
# 	Chunk read error rate: 6.966811370956448%
# Dataset: /WJetsToLNu_2J_TuneCP5_13TeV-amcatnloFXFX-pythia8/RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1/NANOAODSIM
# 	Number of files: 44
# 	File read error rate: 11.363636363636363%
# 	Number of chunks: 6688
# 	Chunk read error rate: 11.857057416267942%
#
# ========================================================
#
# ERROR MESSAGES:
# ----------------------------------------------------
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x150c5bb39750>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x152fcab04850>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x151f5a1039a0>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14965dd2c9a0>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x1469e1b7ffa0>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14d2b2f36680>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14cbfdf3e9e0>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x151ea61772b0>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x1541e28c40d0>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14b172720a00>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14b57061cd30>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x149ea4fe6830>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x15116349ceb0>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x151e050e4fa0>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x149f7f3effa0>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14a943d25ae0>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x1482213a10c0>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14faab3ad930>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x149829bdb970>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14fa9bc6ee90>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14a1567d4370>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14b417ec7370>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14ecff189660>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x154fcce36950>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x151feeae3190>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x1510e724e350>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14bad9f96380>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x149ca9f1fe80>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x146500a8bc70>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to close file: [ERROR] Socket timeout
# 	Chunks with this message: 3
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14ada1249210>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14c5c761e4a0>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14603e0c7160>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14d2b15ca410>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x1469ec47c430>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to close file: [ERROR] Operation expired
# 	Chunks with this message: 36
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14b455d9e380>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x151db06ff550>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14f69bd519c0>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14cbfca7eb60>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14a4223ad750>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x15462bea0d30>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x152883f3da50>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x146884169480>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x151dd0d8db10>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14c77f9f0b80>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14f57a545b10>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14d44e0c0580>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14a423a47e20>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Bytes failed to read from open file: [ERROR] Operation expired
# 	Chunks with this message: 207
# Error message: File did not open properly: [ERROR] Socket timeout
# 	Chunks with this message: 46
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x154bca7347f0>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14b1faec60e0>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x1461a8121ab0>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x1522adc2bca0>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x146256729120>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14ac5d3fcf70>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14d104eb3ee0>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14aa50f5c9d0>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x1471268812a0>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14a7e433e680>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x146865371900>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x149caac3bc70>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14a7cdb7fd60>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14c5e4d0c070>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14b4507e9e10>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x151e03db4940>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14d1069307c0>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14bad9990580>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x152883f3e3b0>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x1465f2e9ce50>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x15200d948bb0>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x153c6064cdc0>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x154d731f8610>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14dd73661e40>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x1486ab6afe50>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x151e06c14ac0>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x1486ab03a8c0>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x1522afef7e80>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: File did not open properly: [ERROR] Operation expired
# 	Chunks with this message: 7916
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x148b18170d60>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x151ea46b3160>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14fba37e0760>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14a0b08f2ce0>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x150f89447a90>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x153c55d15ae0>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14ac01fd0160>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14968d05f130>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x150be66d9540>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14c77e3cf5b0>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x152ba92ab3a0>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x15277f0fa560>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x1461bb0c01f0>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x1527a21bbb80>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x1533f32d2c20>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x153416858190>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x14be070d84c0>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
# Error message: Failed to submit <bound method File.close of <XRootD.client.file.File object at 0x148ef1705750>> request: [ERROR] Invalid operation
# 	Chunks with this message: 1
